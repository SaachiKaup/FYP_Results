# %%
import pandas as pd

# %%
import json

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                        after_merge  \
# 0        1790  def plot(result_pickle_file_path, show, plot_s...
# 1        2433      def stream_logs(self):\n        """Stream ...
# 2       26618      def addRecentProjectFile(self, projectFile...
# 3       26622      def addSfmAugmentation(self, withMVS=False...
# 4       28217      def load_pymathics_doc(self):\n        if ...
#
#                                         before_merge  \
# 0  def plot(result_dict_file, show, plot_save_fil...
# 1      def stream_logs(self):\n        """Stream ...
# 2      def addRecentProjectFile(self, projectFile...
# 3      def addSfmAugmentation(self, withMVS=False...
# 4      def load_pymathics_doc(self):\n        if ...
#
#                                            filename  \
# 0  rqalpha/mod/rqalpha_mod_sys_analyser/__init__.py
# 1                                binderhub/build.py
# 2                                meshroom/ui/app.py
# ...

# %%
drop_columns = [
    "Unnamed: 0", 
    "filename", 
    "full_file_code_after_merge", 
    "full_file_code_before_merge", 
    "function_name", 
    "url", 
    "before_merge_without_docstrings",
    "after_merge_without_docstrings",
    "before_merge_docstrings",
    "after_merge_docstrings",
    "path_to_snippet_before_merge",
    "path_to_snippet_after_merge"
]

# %%
df.drop(drop_columns, axis = 1)
# Out:
#                                              after_merge  \
# 0      def plot(result_pickle_file_path, show, plot_s...
# 1          def stream_logs(self):\n        """Stream ...
# 2          def addRecentProjectFile(self, projectFile...
# 3          def addSfmAugmentation(self, withMVS=False...
# 4          def load_pymathics_doc(self):\n        if ...
# ...                                                  ...
# 14113      def touch_member(self, data, ttl=None, per...
# 14114  def apply_config_changes(before_editing, data,...
# 14115      def set_path_value(config, path, value, pr...
# 14116  def edit_config(obj, cluster_name, force, quie...
# 14117      def is_failover_possible(self, cluster, le...
#
#                                             before_merge  \
# 0      def plot(result_dict_file, show, plot_save_fil...
# 1          def stream_logs(self):\n        """Stream ...
# 2          def addRecentProjectFile(self, projectFile...
# ...

# %%
import json
import requests
api_key = "AIzaSyCuf-_Tq7gKStezexKTa2i2G8Ectg9xw8Q" #saachi key
#api_key = "AIzaSyBmjhopUEEOHLgBwvn0r36e3tsHUqOnEfA"

# %%
import time

# %%
def security_recommendations(buggy_code):
  
  time.sleep(3)
  prompt = {
      "text": buggy_code + '''\nGive a recommendation for making this code more secure:\n
              Give me the most important 3 points to secure this code.\n
              Answer in three sentences only, and be specific.'''
  }

  # Create JSON request body
  raw = json.dumps({"prompt": prompt})

  # Send POST request
  url = "https://generativelanguage.googleapis.com/v1beta2/models/text-bison-001:generateText"
  params = {"key": api_key}
  response = requests.post(url, params=params, data=raw)
  # Check for successful response
  if response.status_code == 200:
      try:
        # Process the response (e.g., extract the generated text)
        data = response.json()
        # print(data['candidates'][0]['output'])
        # print(data)
        return data['candidates'][0]['output']
      except:
        print("Not working")
        print(data)
        return "000_Didnt Work"
  else:
      print(f"Error: {response.status_code}")
      return("000_Error")

# %%
def optimization_recommendations(buggy_code):
  
  time.sleep(3)
  prompt = {
      "text": buggy_code + '''\nGive a recommendation for making this code more Optimized:\n
              Give me the most important 3 points to Optimize this code.\n
              Answer in three sentences only, and be specific.'''
  }

  # Create JSON request body
  raw = json.dumps({"prompt": prompt})

  # Send POST request
  url = "https://generativelanguage.googleapis.com/v1beta2/models/text-bison-001:generateText"
  params = {"key": api_key}
  response = requests.post(url, params=params, data=raw)
  # Check for successful response
  if response.status_code == 200:
      try:
        # Process the response (e.g., extract the generated text)
        data = response.json()
        # print(data['candidates'][0]['output'])
        # print(data)
        return data['candidates'][0]['output']
      except:
        print("Not working")
        print(data)
        return "000_Didnt Work"
  else:
      print(f"Error: {response.status_code}")
      return("000_Error")

# %%
import csv

# %%
# Import writer class from csv module
from csv import writer
 # List that we want to add as a new row

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14118 entries, 0 to 14117
# Data columns (total 17 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Unnamed: 0                       14118 non-null  int64
#  1   after_merge                      14118 non-null  object
#  2   before_merge                     14118 non-null  object
#  3   filename                         14118 non-null  object
#  4   full_file_code_after_merge       14118 non-null  object
#  5   full_file_code_before_merge      14118 non-null  object
#  6   function_name                    14118 non-null  object
#  7   url                              14118 non-null  object
#  8   source code and errors           14118 non-null  object
#  9   full_traceback                   14118 non-null  object
#  10  traceback_type                   14118 non-null  object
#  11  before_merge_without_docstrings  14118 non-null  object
# ...

# %%
headers = ['id','after_merge',	'before_merge','source code and errors','full_traceback','traceback_type', 'secure_results','optimized_results']
with open('Recommend_optimized.csv', 'a+') as f_object:
# obj = [ i, df['after_merge'][i], df['before_merge'][i], df['source code and errors'][i], df['full_traceback'][i], df['traceback_type'][i], df['secure_results'][i], opti ]
        writer_object = writer(f_object)
        writer_object.writerow(headers)
 
    # Close the file object
        f_object.close()

# %%
def row_content(indx, df, palm_optimization_recommendations, palm_security_recommendations):
    return [
        indx,
        df['after_merge'][indx],
        df['before_merge'][indx],
        df['source code and errors'][indx],
        df['full_traceback'][indx],
        df['traceback_type'][indx],
        palm_security_recommendations,
        palm_optimization_recommendations
    ]

# %%
# obj = ['id','after_merge',	'before_merge','source code and errors','full_traceback','traceback_type', 'secure_results','optimied_results']
with open('Recommend_optimized.csv', 'a+', encoding="utf-8") as f_object:
    for indx in df.index[2003:2500]:
#         _optimization_recommendations = optimization_recommendations(df['before_merge'][i])
        print()
#         obj = [ i, df['after_merge'][i], df['before_merge'][i], df['source code and errors'][i], df['full_traceback'][i], df['traceback_type'][i], df['secure_results'][i], opti ]
        writer_object = writer(f_object)
        writer_object.writerow(row_content(indx, df, optimization_recommendations(df['before_merge'][indx]), security_recommendations(df['before_merge'][indx])))
        print(indx)
 
    # Close the file object
    f_object.close()
# Out:
# 2003
#
# 2004
#
# 2005
#
# 2006
#
# 2007
#
# 2008
#
# 2009
#
# 2010
#
# 2011
#
# 2012
#
# 2013
#
# 2014
#
# 2015
#
# 2016
#
# 2017
#
# 2018
#
# 2019
#
# 2020
#
# 2021
#
# 2022
#
# 2023
#
# 2024
#
# 2025
#
# 2026
#
# 2027
#
# 2028
#
# 2029
#
# 2030
#
# 2031
#
# 2032
#
# 2033
#
# 2034
#
# 2035
#
# 2036
#
# 2037
#
# 2038
#
# 2039
#
# 2040
#
# 2041
#
# 2042
#
# 2043
#
# 2044
#
# 2045
#
# 2046
#
# 2047
#
# 2048
#
# 2049
#
# 2050
#
# 2051
#
# 2052
#
# 2053
#
# 2054
#
# 2055
#
# 2056
#
# 2057
#
# 2058
#
# 2059
#
# 2060
#
# 2061
#
# 2062
#
# 2063
#
# 2064
#
# 2065
#
# 2066
#
# 2067
#
# 2068
#
# 2069
#
# 2070
#
# Error: 500
# 2071
#
# Error: 500
# 2072
#
# 2073
#
# 2074
#
# 2075
#
# 2076
#
# 2077
#
# 2078
#
# 2079
#
# 2080
#
# 2081
#
# 2082
#
# 2083
#
# 2084
#
# 2085
#
# 2086
#
# 2087
#
# 2088
#
# 2089
#
# 2090
#
# 2091
#
# 2092
#
# 2093
#
# 2094
#
# 2095
#
# 2096
#
# 2097
#
# 2098
#
# 2099
#
# 2100
#
# 2101
#
# 2102
#
# 2103
#
# 2104
#
# 2105
#
# 2106
#
# 2107
#
# 2108
#
# 2109
#
# 2110
#
# ...

# %%
df_new = pd.read_csv('Recommend_optimized.csv',encoding='unicode_escape')
df_new
# Out:
#         id                                        after_merge  \
# 0        0      def _smart_save(\r\n            self, fnam...
# 1        1      def save(\r\n            self, fname_or_ha...
# 2        2  def pickle(obj, fname, protocol=PICKLE_PROTOCO...
# 3        3      def load(cls, *args, **kwargs):\r\n       ...
# 4        4      def __init__(\r\n            self, sentenc...
# ...    ...                                                ...
# 1877  1877      def startProxyConnect(self):\r\n        ""...
# 1878  1878      def as_view(cls, actions=None, **initkwarg...
# 1879  1879          def view(request, *args, **kwargs):\r\...
# 1880  2001      def get_serializer_fields(self, path, meth...
# 1881  2002      def as_form_field(self):\n        if self....
#
#                                            before_merge  \
# 0         def _smart_save(self, fname, separately=No...
# 1         def save(self, fname_or_handle, separately...
# ...

# %%
df_new.tail()
# Out:
#         id                                        after_merge  \
# 1877  1877      def startProxyConnect(self):\r\n        ""...
# 1878  1878      def as_view(cls, actions=None, **initkwarg...
# 1879  1879          def view(request, *args, **kwargs):\r\...
# 1880  2001      def get_serializer_fields(self, path, meth...
# 1881  2002      def as_form_field(self):\n        if self....
#
#                                            before_merge  \
# 1877      def startProxyConnect(self):\r\n        ""...
# 1878      def as_view(cls, actions=None, **initkwarg...
# 1879          def view(request, *args, **kwargs):\r\...
# 1880      def get_serializer_fields(self, path, meth...
# 1881      def as_form_field(self):\n        values =...
#
#                                  source code and errors  \
# 1877  [{'piece_type': 'error message', 'piece_conten...
# 1878  [{'piece_type': 'other', 'piece_content': "pip...
# 1879  [{'piece_type': 'other', 'piece_content': "pip...
# ...
